# %%
plik = open("dane.txt", "r")

zawartosc = plik.readlines()
print(zawartosc)
plik.close()
# Out:
# ['100\n', '200\n', '300\n', '400\n', '500']

# %%
for item in zawartosc:
    print(item)
# Out:
# 100
#
# 200
#
# 300
#
# 400
#
# 500
