# %%
import pandas as pd

wynagrodzenia = {
    "Styczeń": [5000, 6000, 7000, 8000],
    "Luty": [5100, 6200, 7300, 8400]
}

# %%
df = pd.DataFrame(wynagrodzenia)

# %%
print(df)
# Out:
#    Styczeń  Luty
# 0     5000  5100
# 1     6000  6200
# 2     7000  7300
# 3     8000  8400

# %%
df.loc[0:2]
# Out:
#    Styczeń  Luty
# 0     5000  5100
# 1     6000  6200
# 2     7000  7300

# %%
df = pd.DataFrame(wynagrodzenia, index=["Pracownik A", "Pracownik B", "Pracownik C", "Pracownik D"])
df
# Out:
#              Styczeń  Luty
# Pracownik A     5000  5100
# Pracownik B     6000  6200
# Pracownik C     7000  7300
# Pracownik D     8000  8400
