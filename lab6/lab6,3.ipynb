# %%
import pandas as pd

wynagrodzenia = {
    "Styczeń": [5000, 6000, 7000, 8000],
    "Luty": [5100, 6200, 7300, 8400]
}

# %%
df = pd.DataFrame(wynagrodzenia)

# %%
print(df)
# Out:
#    Styczeń  Luty
# 0     5000  5100
# 1     6000  6200
# 2     7000  7300
# 3     8000  8400
