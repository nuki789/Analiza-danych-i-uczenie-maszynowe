# %%
import pandas as pd
lista = [5000, 6000, 4500, 3000]

wynagrodzenia = pd.Series(lista, index = ["Kaczmarek", "Nowak", "Kowalski", "Maćkowiak"])

print(wynagrodzenia)
# Out:
# Kaczmarek    5000
# Nowak        6000
# Kowalski     4500
# Maćkowiak    3000
# dtype: int64

# %%
wynagrodzenia["Kowalski"]
# Out:
# np.int64(4500)
