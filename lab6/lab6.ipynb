# %%
import pandas as pd

lista = [4, 5, (1, 2, 3), "txt", 1.0]

szereg = pd.Series(lista)

print(szereg)
# Out:
# 0            4
# 1            5
# 2    (1, 2, 3)
# 3          txt
# 4          1.0
# dtype: object
