# %%
import pandas as pd

miesiace = {"Styczeń": 1, "Luty": 2, "Marzec": 3, "Kwiecień": 4}
kalendarz = pd.Series(miesiace)
print(kalendarz)
# Out:
# Styczeń     1
# Luty        2
# Marzec      3
# Kwiecień    4
# dtype: int64

# %%
kalendarz["Marzec"]
# Out:
# np.int64(3)
